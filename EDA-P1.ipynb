# %% [markdown]
# <h2 align="center">AtliQ Hotels Data Analysis Project<h2>

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ***
# ### ==> 1. Data Import and Data Exploration
# ***

# %% [markdown]
# ### Datasets
# We have 5 csv file
#
#    - dim_date.csv
#    - dim_hotels.csv
#    - dim_rooms.csv
#    - fact_aggregated_bookings
#    - fact_bookings.csv

# %% [markdown]
# **Read bookings data in a datagrame**

# %%
df_bookings = pd.read_csv('datasets/fact_bookings.csv')

# %% [markdown]
# **Explore bookings data**

# %%
df_bookings.head(4)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized
# 0              10010             10010
# 1               9100              3640
# 2            9100000              9100
# 3               9100              3640

# %%
df_bookings.shape
# Out:
# (134590, 12)

# %%
df_bookings['room_category'].unique()
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4'], dtype=object)

# %%
df_bookings['booking_platform'].unique()
# Out:
# array(['direct online', 'others', 'logtrip', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline'], dtype=object)

# %% [markdown]
# __Function that shows how many bookings are made per platform?__

# %%
df_bookings['booking_platform'].value_counts()
# Out:
# booking_platform
# others            55066
# makeyourtrip      26898
# logtrip           14756
# direct online     13379
# tripster           9630
# journey            8106
# direct offline     6755
# Name: count, dtype: int64

# %%
df_bookings['booking_platform'].value_counts().plot(kind='bar', color='orange')

plt.title('Bookings per Booking_Platform')
plt.xlabel('Booking Platform')
plt.ylabel('No. of Bookings')
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]),
#  [Text(0, 0, 'others'),
#   Text(1, 0, 'makeyourtrip'),
#   Text(2, 0, 'logtrip'),
#   Text(3, 0, 'direct online'),
#   Text(4, 0, 'tripster'),
#   Text(5, 0, 'journey'),
#   Text(6, 0, 'direct offline')])

# %% [markdown]
# __Stats of data__

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %% [markdown]
# __Like in 4th column if we want to see specific info only__

# %%
df_bookings.revenue_generated.max(),df_bookings.revenue_generated.min()
# Below shows revenue per booking
# Out:
# (np.int64(28560000), np.int64(6500))

# %% [markdown]
# **Read rest of File**

# %%
df_date = pd.read_csv('datasets/dim_date.csv')
df_hotels = pd.read_csv('datasets/dim_hotels.csv')
df_rooms = pd.read_csv('datasets/dim_rooms.csv')
df_agg_bookings  =pd.read_csv('datasets/fact_aggregated_bookings.csv')

# %%
df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df_rooms.value_counts()
# Out:
# room_id  room_class
# RT1      Standard        1
# RT2      Elite           1
# RT3      Premium         1
# RT4      Presidential    1
# Name: count, dtype: int64

# %%
df_hotels.head(4)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi

# %%
df_hotels.category.value_counts()
# Out:
# category
# Luxury      16
# Business     9
# Name: count, dtype: int64

# %%
df_hotels.city.value_counts().sort_values()
# Out:
# city
# Delhi        5
# Hyderabad    6
# Bangalore    6
# Mumbai       8
# Name: count, dtype: int64

# %%
df_hotels.city.value_counts().sort_values().plot(kind='barh')
plt.title('Hotels per city')
plt.xlabel('No. of hotels')
plt.ylabel('City')
# Out:
# Text(0, 0.5, 'City')

# %% [markdown]
# ***
# ## ==> 2. Data Cleaning
# ***

# %% [markdown]
# #### Data Cleaning for no. of guests

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
# Found bookings with negative guest counts, which are impossible in real-world hotel bookings.

# %%
df_bookings[df_bookings.no_guests<=0]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 17924    May122218559RT44        18559    12/5/2022     12/5/2022
# 18020    May122218561RT22        18561     8/5/2022     12/5/2022
# 18119   May122218562RT311        18562     5/5/2022     12/5/2022
# 18121   May122218562RT313        18562    10/5/2022     12/5/2022
# 56715    Jun082218562RT12        18562     5/6/2022      8/6/2022
# 119765  Jul202219560RT220        19560     19-07-22      20-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# 3           2/5/2022       -2.0           RT1           others            NaN
# ...

# %% [markdown]
# #### So we have to  only store those records with positive no. of guests

# %%
df_bookings = df_bookings[df_bookings.no_guests>0]
df_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df_bookings.shape
# Out:
# (134578, 12)

# %% [markdown]
#  __Now no. of rows reduced from 134590 to 134578__

# %% [markdown]
# #### Data Cleaning for revenue_generated

# %%
df_bookings.revenue_generated.min(), df_bookings.revenue_generated.max()
# Out:
# (np.int64(6500), np.int64(28560000))

# %% [markdown]
# ##### Maximum revenue per booking was ₹2.85 crore, which is unrealistic for a hotel booking. Applied the 3-sigma rule to identify and remove extreme outliers.

# %% [markdown]
# ##### So to clean
# ##### 1st we had to find out average revenue generated & 3 standard deviation
# ##### and filter out revenue higher than 3 step standard deviation

# %%
avg, std = df_bookings.revenue_generated.mean(), df_bookings.revenue_generated.std()
avg, std
# Out:
# (np.float64(15378.036937686695), np.float64(93040.1549314641))

# %%
higher_limit = avg + 3*std
higher_limit
# Out:
# np.float64(294498.50173207896)

# %%
lower_limit = avg - 3*std
lower_limit
# Out:
# np.float64(-263742.4278567056)

# %%
df_bookings[df_bookings.revenue_generated <= 0]
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized]
# Index: []

# %%
df_bookings[df_bookings.revenue_generated>higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 111      May012216559RT32        16559     29-04-22      1/5/2022
# 315      May012216562RT22        16562     28-04-22      1/5/2022
# 562     May012217559RT118        17559     26-04-22      1/5/2022
# 129176   Jul282216562RT26        16562     21-07-22      28-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 2           4/5/2022        2.0           RT1          logtrip            5.0
# 111         2/5/2022        6.0           RT3    direct online            NaN
# 315         4/5/2022        2.0           RT2   direct offline            3.0
# 562         2/5/2022        2.0           RT1           others            NaN
# 129176      29-07-22        2.0           RT2    direct online            3.0
#
#        booking_status  revenue_generated  revenue_realized
# ...

# %%
df_bookings = df_bookings[df_bookings.revenue_generated<= higher_limit]
df_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# 7        May012216558RT18        16558     26-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df_bookings.shape
# Out:
# (134573, 12)

# %% [markdown]
# #### Data Cleaning for revenue_realized

# %%
df_bookings.revenue_realized.describe()
# Out:
# count    134573.000000
# mean      12695.983585
# std        6927.791692
# min        2600.000000
# 25%        7600.000000
# 50%       11700.000000
# 75%       15300.000000
# max       45220.000000
# Name: revenue_realized, dtype: float64

# %% [markdown]
# ##### Now although seeing the min & max revenue_realized satisfies but still to check any outlier lets do 3 std

# %%
avg, std = df_bookings.revenue_realized.mean(), df_bookings.revenue_realized.std()
avg, std
# Out:
# (np.float64(12695.983585117372), np.float64(6927.791692242814))

# %%
higher_limit = avg + 3*std
higher_limit
# Out:
# np.float64(33479.358661845814)

# %%
df_bookings[df_bookings.revenue_realized > higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 137      May012216559RT41        16559     27-04-22      1/5/2022
# 139      May012216559RT43        16559     1/5/2022      1/5/2022
# 143      May012216559RT47        16559     28-04-22      1/5/2022
# 149     May012216559RT413        16559     24-04-22      1/5/2022
# 222      May012216560RT45        16560     30-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134328   Jul312219560RT49        19560     31-07-22      31-07-22
# 134331  Jul312219560RT412        19560     31-07-22      31-07-22
# 134467   Jul312219562RT45        19562     28-07-22      31-07-22
# 134474  Jul312219562RT412        19562     25-07-22      31-07-22
# 134581   Jul312217564RT42        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 137         7/5/2022        4.0           RT4           others            NaN
# ...

# %%
# Note - all the above have RT4 room category which comes in class- Presidential

# %%
df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %% [markdown]
# ### Pure Analysis of RT4

# %%
df_bookings[df_bookings.room_category=='RT4'].revenue_realized.describe()
# Out:
# count    16073.000000
# mean     23440.103652
# std       9048.865206
# min       7600.000000
# 25%      19000.000000
# 50%      26600.000000
# 75%      32300.000000
# max      45220.000000
# Name: revenue_realized, dtype: float64

# %%
## 3 std on it

# %%
23440 + 3*9048
# Out:
# 50584

# %%
# So the outlier here is approx  Rs.50,000 which this dataset of bookings does have for RT4 as max is - 45,220

# %% [markdown]
# ### Check for NA Values

# %%
df_bookings.isnull().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                3
# room_category            0
# booking_platform         0
# ratings_given        77907
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %%
# Only ratings have NA values which is not a big issue

# %% [markdown]
# ***
# ### ==> 3. Data Transformation
# ***

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#     occ_pct
# 0  0.833333
# 1  0.933333
# 2  0.766667
# 3  1.578947
# 4  0.947368

# %%
# Occupancy rate
25/30
# Out:
# 0.8333333333333334

# %%
# Created Occupancy Rate KPI:
# Occupancy Rate = Successful Bookings / Capacity

# %%
df_agg_bookings['occ_pct']  = df_agg_bookings['successful_bookings']/ df_agg_bookings['capacity']

# %%
df_agg_bookings['occ_pct'].head(4)
# Out:
# 0    0.833333
# 1    0.933333
# 2    0.766667
# 3    1.578947
# Name: occ_pct, dtype: float64

# %%
df_agg_bookings['occ_pct']  = df_agg_bookings['occ_pct'].apply(lambda x: round(x*100,2))
df_agg_bookings.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
#
#    occ_pct
# 0    83.33
# 1    93.33
# 2    76.67
# 3   157.89

# %% [markdown]
# There are various types of data transformations that you may have to perform based on the need. Few examples of data transformations are

# %% [markdown]
# * Creating new columns
# * Normalization
# * Merging Data
# * Aggregation

# %% [markdown]
# ***
# ### ==> 4.Insights Generation
# ***

# %% [markdown]
#  __1.What is the average occupancy rate in each of the room categories ?__

# %%
df_agg_bookings.groupby('room_category')['occ_pct'].mean().round(2)
# Out:
# room_category
# RT1    58.22
# RT2    58.04
# RT3    58.03
# RT4    59.30
# Name: occ_pct, dtype: float64

# %%
df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df = pd.merge(df_agg_bookings,df_rooms, left_on='room_category' ,right_on='room_id')
df.tail()
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
#        occ_pct room_id    room_class
# 9195  0.722222     RT4  Presidential
# 9196  0.722222     RT4  Presidential
# 9197  0.500000     RT4  Presidential
# 9198  0.500000     RT4  Presidential
# 9199  0.750000     RT4  Presidential

# %%
df.groupby('room_class')['occ_pct'].mean().round(2)
# Out:
# room_class
# Elite           0.58
# Premium         0.58
# Presidential    0.59
# Standard        0.58
# Name: occ_pct, dtype: float64

# %%
df.drop('room_id',axis=1,inplace=True)
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    occ_pct room_class
# 0    83.33   Standard
# 1    93.33   Standard
# 2    76.67   Standard
# 3   157.89   Standard
# 4    94.74   Standard

# %% [markdown]
#  __2. Print average occupancy rate per city__

# %%
df_hotels.head(3)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi

# %%
df= pd.merge(df,df_hotels,on='property_id')
df.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
#
#     occ_pct room_id room_class  property_name  category       city
# 0  0.833333     RT1   Standard  Atliq Exotica    Luxury     Mumbai
# 1  0.933333     RT1   Standard      Atliq Bay    Luxury  Bangalore
# 2  0.766667     RT1   Standard   Atliq Palace  Business  Bangalore

# %%
df.groupby('city')['occ_pct'].mean().plot(kind='bar', color='green', figsize=(6,4))
plt.title("Average Occupancy Rate by City")
plt.xlabel("City")
plt.ylabel("Occupancy %")
plt.show()
plt.xticks(rotation=45)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0.0, 0, '0.0'),
#   Text(0.2, 0, '0.2'),
#   Text(0.4, 0, '0.4'),
#   Text(0.6000000000000001, 0, '0.6'),
#   Text(0.8, 0, '0.8'),
#   Text(1.0, 0, '1.0')])

# %% [markdown]
# __3. When was the occupancy better? Weekday or Weekend?__

# %%
 df.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
#
#    occ_pct room_class  property_name  category       city
# 0    83.33   Standard  Atliq Exotica    Luxury     Mumbai
# 1    93.33   Standard      Atliq Bay    Luxury  Bangalore
# 2    76.67   Standard   Atliq Palace  Business  Bangalore

# %%
df_date
# Out:
#          date  mmm yy week no  day_type
# 0    1-May-22  22-May    W 19   weekend
# 1    2-May-22  22-May    W 19  weekeday
# 2    3-May-22  22-May    W 19  weekeday
# 3    4-May-22  22-May    W 19  weekeday
# 4    5-May-22  22-May    W 19  weekeday
# ..        ...     ...     ...       ...
# 87  27-Jul-22  22-Jul    W 31  weekeday
# 88  28-Jul-22  22-Jul    W 31  weekeday
# 89  29-Jul-22  22-Jul    W 31  weekeday
# 90  30-Jul-22  22-Jul    W 31   weekend
# 91  31-Jul-22  22-Jul    W 32   weekend
#
# [92 rows x 4 columns]

# %%
df = pd.merge(df,df_date, left_on="check_in_date",right_on='date')
df.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
#
#    occ_pct room_class  property_name  category       city      date  mmm yy  \
# 0    83.33   Standard  Atliq Exotica    Luxury     Mumbai  1-May-22  22-May
# 1    93.33   Standard      Atliq Bay    Luxury  Bangalore  1-May-22  22-May
# 2    76.67   Standard   Atliq Palace  Business  Bangalore  1-May-22  22-May
#
#   week no day_type
# 0    W 19  weekend
# 1    W 19  weekend
# 2    W 19  weekend

# %%
df.groupby('day_type')['occ_pct'].mean().round(2)
# Out:
# day_type
# weekeday    51.82
# weekend     74.24
# Name: occ_pct, dtype: float64

# %%
### So weekend has better occupancy % for obvious reasons

# %% [markdown]
# __4. In the month of June, what is occupancy for different cities__

# %%
df['mmm yy'].unique()
# Out:
# array(['22-May', '22-Jun', '22-Jul'], dtype=object)

# %%
df_jun_22= df[df['mmm yy']=='22-Jun']
df_jun_22.tail(3)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 6097        16560     30-Jun-22           RT4                    3       7.0
# 6098        19558     30-Jun-22           RT4                    3       7.0
# 6099        17561     30-Jun-22           RT4                    3       4.0
#
#       occ_pct    room_class property_name  category       city       date  \
# 6097    42.86  Presidential    Atliq City  Business      Delhi  30-Jun-22
# 6098    42.86  Presidential  Atliq Grands    Luxury  Bangalore  30-Jun-22
# 6099    75.00  Presidential     Atliq Blu    Luxury     Mumbai  30-Jun-22
#
#       mmm yy week no  day_type
# 6097  22-Jun    W 27  weekeday
# 6098  22-Jun    W 27  weekeday
# 6099  22-Jun    W 27  weekeday

# %%
df_jun_22.groupby('city')['occ_pct'].mean().round(2).sort_values(ascending=False)
# Out:
# city
# Delhi        61.46
# Mumbai       57.79
# Hyderabad    57.69
# Bangalore    55.95
# Name: occ_pct, dtype: float64

# %% [markdown]
# **5: We got new data for the month of august. Append that to existing data**

# %%
df_august= pd.read_csv('datasets/new_data_august.csv')
df_august.head(3)
# Out:
#    property_id  property_name  category       city room_category room_class  \
# 0        16559  Atliq Exotica    Luxury     Mumbai           RT1   Standard
# 1        19562      Atliq Bay    Luxury  Bangalore           RT1   Standard
# 2        19563   Atliq Palace  Business  Bangalore           RT1   Standard
#
#   check_in_date  mmm yy week no  day_type  successful_bookings  capacity  \
# 0      1-Aug-22  22-Aug    W 32  weekeday                   30        30
# 1      1-Aug-22  22-Aug    W 32  weekeday                   21        30
# 2      1-Aug-22  22-Aug    W 32  weekeday                   23        30
#
#      occ%
# 0  100.00
# 1   70.00
# 2   76.67

# %%
df.shape
# Out:
# (9200, 14)

# %%
df_august.shape
# Out:
# (7, 13)

# %%
df_august.columns
# Out:
# Index(['property_id', 'property_name', 'category', 'city', 'room_category',
#        'room_class', 'check_in_date', 'mmm yy', 'week no', 'day_type',
#        'successful_bookings', 'capacity', 'occ%'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['property_id', 'check_in_date', 'room_category', 'successful_bookings',
#        'capacity', 'occ_pct', 'room_class', 'property_name', 'category',
#        'city', 'date', 'mmm yy', 'week no', 'day_type'],
#       dtype='object')

# %%
latest_df = pd.concat([df,df_august],axis=0,ignore_index=True)
latest_df.tail(3)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 9204        19560      1-Aug-22           RT1                   20      26.0
# 9205        17561      1-Aug-22           RT1                   18      26.0
# 9206        17564      1-Aug-22           RT1                   10      16.0
#
#       occ_pct room_class  property_name  category       city date  mmm yy  \
# 9204      NaN   Standard     Atliq City  Business  Bangalore  NaN  22-Aug
# 9205      NaN   Standard      Atliq Blu    Luxury     Mumbai  NaN  22-Aug
# 9206      NaN   Standard  Atliq Seasons  Business     Mumbai  NaN  22-Aug
#
#      week no  day_type   occ%
# 9204    W 32  weekeday  76.92
# 9205    W 32  weekeday  69.23
# 9206    W 32  weekeday  62.50

# %%
latest_df.shape
# Out:
# (9207, 15)

# %% [markdown]
# __6. Print revenue realized per city__

# %%
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 5  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 6  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
# 7  May012216558RT18        16558     26-04-22      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
# 5        2.0           RT1           others            4.0    Checked Out
# 6        2.0           RT1           others            NaN      Cancelled
# 7        2.0           RT1          logtrip            NaN        No Show
#
#    revenue_generated  revenue_realized
# ...

# %%
df_hotels.head(4)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi

# %%
df_bookings_all= pd.merge(df_bookings,df_hotels,on='property_id')
df_bookings_all.head(4)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 1  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 2  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 3  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
# 3        2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized property_name category   city
# 0               9100              3640  Atliq Grands   Luxury  Delhi
# 1              10920             10920  Atliq Grands   Luxury  Delhi
# ...

# %%
df_bookings_all.groupby('city')['revenue_realized'].sum()
# Out:
# city
# Bangalore    420383550
# Delhi        294404488
# Hyderabad    325179310
# Mumbai       668569251
# Name: revenue_realized, dtype: int64

# %% [markdown]
# __7. Print Month by month revenue__

# %%
df_date.head(3)
# Out:
#        date  mmm yy week no  day_type
# 0  1-May-22  22-May    W 19   weekend
# 1  2-May-22  22-May    W 19  weekeday
# 2  3-May-22  22-May    W 19  weekeday

# %%
df_date['mmm yy'].unique()
# Out:
# array(['22-May', '22-Jun', '22-Jul'], dtype=object)

# %%
df_bookings_all.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 1  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 2  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city
# 0               9100              3640  Atliq Grands   Luxury  Delhi
# 1              10920             10920  Atliq Grands   Luxury  Delhi
# 2               9100              9100  Atliq Grands   Luxury  Delhi

# %%
# Checking date datatype

# %%
df_bookings_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134573 entries, 0 to 134572
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134573 non-null  object
#  1   property_id        134573 non-null  int64
#  2   booking_date       134573 non-null  object
#  3   check_in_date      134573 non-null  object
#  4   checkout_date      134573 non-null  object
#  5   no_guests          134573 non-null  float64
#  6   room_category      134573 non-null  object
#  7   booking_platform   134573 non-null  object
#  8   ratings_given      56676 non-null   float64
#  9   booking_status     134573 non-null  object
#  10  revenue_generated  134573 non-null  int64
#  11  revenue_realized   134573 non-null  int64
#  12  property_name      134573 non-null  object
#  13  category           134573 non-null  object
#  14  city               134573 non-null  object
# ...

# %%
df_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      92 non-null     object
#  1   mmm yy    92 non-null     object
#  2   week no   92 non-null     object
#  3   day_type  92 non-null     object
# dtypes: object(4)
# memory usage: 3.0+ KB

# %%
# Changing data type of 'check_in_date' in df_bookings & 'date' in df_date

# %%
df_date['date'] = pd.to_datetime(df_date['date'])
df_date.head(3)
# Out:
# C:\Users\T480\AppData\Local\Temp\ipykernel_6924\248606528.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_date['date'] = pd.to_datetime(df_date['date'])
#         date  mmm yy week no  day_type
# 0 2022-05-01  22-May    W 19   weekend
# 1 2022-05-02  22-May    W 19  weekeday
# 2 2022-05-03  22-May    W 19  weekeday

# %%
df_bookings_all['check_in_date'] = pd.to_datetime(df_bookings_all['check_in_date'],format='mixed',dayfirst=True)
df_bookings_all.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22    2022-05-01      2/5/2022
# 1  May012216558RT15        16558     27-04-22    2022-05-01      2/5/2022
# 2  May012216558RT16        16558     1/5/2022    2022-05-01      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city
# 0               9100              3640  Atliq Grands   Luxury  Delhi
# 1              10920             10920  Atliq Grands   Luxury  Delhi
# 2               9100              9100  Atliq Grands   Luxury  Delhi

# %%
df_bookings_all = pd.merge(df_bookings_all,df_date, left_on='check_in_date',right_on='date')
df_bookings_all.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22    2022-05-01      2/5/2022
# 1  May012216558RT15        16558     27-04-22    2022-05-01      2/5/2022
# 2  May012216558RT16        16558     1/5/2022    2022-05-01      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city  \
# 0               9100              3640  Atliq Grands   Luxury  Delhi
# 1              10920             10920  Atliq Grands   Luxury  Delhi
# 2               9100              9100  Atliq Grands   Luxury  Delhi
#
#         date  mmm yy week no day_type
# 0 2022-05-01  22-May    W 19  weekend
# ...

# %%
df_bookings_all.groupby('mmm yy')['revenue_realized'].sum()
# Out:
# mmm yy
# 22-Jul    572843348
# 22-Jun    553925855
# 22-May    581767396
# Name: revenue_realized, dtype: int64

# %% [markdown]
# # Executive Summary
#
# ## Key Findings
#
# 1. Weekend occupancy was higher than weekday occupancy.
#
# 2. Certain room categories generated higher revenue.
#
# 3. Invalid guest records were found and removed.
#
# 4. Revenue outliers were identified using the 3-sigma rule.
#
# ## Recommendations
#
# - Increase pricing during peak occupancy periods.
# - Focus promotions on lower-performing room categories.
# - Improve booking validation to prevent invalid entries.
